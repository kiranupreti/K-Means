# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
a=np.array([2,3,4,7,8,9])
b=np.array([1,2,1,7,6,8])

# %%
plt.scatter(a,b)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data=np.zeros((6,2))
data[:,0]=a
data[:,1]=b
print(data.shape)
print(data)
# Out:
# (6, 2)
# [[2. 1.]
#  [3. 2.]
#  [4. 1.]
#  [7. 7.]
#  [8. 6.]
#  [9. 8.]]

# %%
a=np.random.choice(range(data.shape[0]),2)#here we are choosing random element out the arrar of size 2
print(a)
# Out:
# [3 2]

# %%
#    for i in range(len(a1)):
#        centroids[i]=data[c[i],:]
#    print(centroids)
centroids= data[a,:]   
print(centroids)
centroids[0]=centroids[0,:]
centroids[1]=centroids[-1,:]

print('centroids_0 is',centroids[0])
print('centroid_1 is',centroids[1])
# Out:
# [[7. 7.]
#  [4. 1.]]
# centroids_0 is [7. 7.]
# centroid_1 is [4. 1.]

# %%
#for iter in range(3):
for i in range(2):
    k=2
    cluster_0=[]
    cluster_1=[]
    for x in data:
        distances=[]
        for c in centroids:
            d=np.dot(x-c,x-c)
            distances.append(d)
        #distances=np.array(distances)
        print('distances are',distances)
        min_dis_index=distances.index(min(distances))
        if(min_dis_index==0):
            cluster_0.append(x)
        else:
            cluster_1.append(x)
            
    cluster_0=np.array(cluster_0)
    print(' updated first cluster are',cluster_0)
    cluster_1=np.array(cluster_1)
    print(' updated second cluster are',cluster_1)
    centroids[0]=cluster_0.mean(axis=0)
    print(' updatd first centroids are',centroids[0])
    centroids[1]=cluster_1.mean(axis=0)
    print(' updatd second centroids are',centroids[1])


print('centroids are',centroids)
# Out:
# distances are [98.0, 61.0]
# distances are [72.0, 41.0]
# distances are [74.0, 41.0]
# distances are [5.0, 2.0]
# distances are [5.0, 0.0]
# distances are [0.0, 5.0]
#  updated first cluster are [[9. 8.]]
#  updated second cluster are [[2. 1.]
#  [3. 2.]
#  [4. 1.]
#  [7. 7.]
#  [8. 6.]]
#  updatd first centroids are [9. 8.]
#  updatd second centroids are [4.8 3.4]
# distances are [98.0, 13.599999999999998]
# distances are [72.0, 5.199999999999999]
# distances are [74.0, 6.3999999999999995]
# distances are [5.0, 17.8]
# distances are [5.0, 17.000000000000004]
# distances are [0.0, 38.8]
#  updated first cluster are [[7. 7.]
#  [8. 6.]
#  [9. 8.]]
#  updated second cluster are [[2. 1.]
#  [3. 2.]
#  [4. 1.]]
#  updatd first centroids are [8. 7.]
#  updatd second centroids are [3.         1.33333333]
# centroids are [[8.         7.        ]
#  [3.         1.33333333]]

# %%
plt.scatter(data[:,0],data[:,1])
plt.plot(centroids[:,0],centroids[:,1],'r*',markersize=20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
